# %% [markdown]
# # Preparação dos dados
# Nesse notebook vamos preparar os dados que utilizaremos ao longo do desenvolvimento do projeto. Os datasets aqui utilizados são importados do portal de dados abertos da UFRN (http://dados.ufrn.br/).
#
# Para esse estudo, analisaremos apenas os dados do curso de Ciência e Tecnologia da UFRN, mais espeficamente a disciplina de Cálculo 2, onde tentaremos prever as possiveis reprovações dos alunos se baseando em seu histórico e na nota da primeira unidade na disciplina.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importando os dados
# Vamos importar e já separar os escolhidos.

# %%
lista_anos_analisados = ['20151', '20152', '20161', '20162', '20171', '20172'] # 20172 vai ficar para validação

matriculas_geral = pd.DataFrame()
for ano in lista_anos_analisados:
    matriculas = pd.read_csv(f"data/matriculas_pos_limpeza_{ano}.csv", sep=";")
    
    matriculas_geral = pd.concat([matriculas_geral, matriculas])
# Out:
# /home/rafael/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys

# %%
matriculas_geral.shape
# Out:
# (34473, 12)

# %%
matriculas_geral.head()
# Out:
#    Unnamed: 0  Unnamed: 10  descricao                          discente  \
# 0       34925          NaN  REPROVADO  6c4acceb9b1288b61d893dc1b5005764
# 1       34926          NaN  REPROVADO  6c4acceb9b1288b61d893dc1b5005764
# 2       34927          NaN  REPROVADO  6c4acceb9b1288b61d893dc1b5005764
# 3       34928          NaN   APROVADO  bb67c2ca87d0e1fcf027b2f0f6df4221
# 4       34929          NaN   APROVADO  bb67c2ca87d0e1fcf027b2f0f6df4221
#
#    faltas_unidade    id_curso  id_turma  media_final  nota  \
# 0             0.0  10320810.0   1242602          0.0   0.0
# 1             0.0  10320810.0   1242602          0.0   0.0
# 2             0.0  10320810.0   1242602          0.0   0.0
# 3             0.0  10320810.0   1242602          8.5   9.0
# 4             0.0  10320810.0   1242602          8.5  10.0
#
#    numero_total_faltas reposicao  unidade
# 0                  0.0         f      1.0
# 1                  0.0         f      2.0
# 2                  0.0         f      3.0
# 3                  0.0         f      2.0
# 4                  0.0         f      3.0

# %%
matriculas_geral.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 10', 'descricao', 'discente', 'faltas_unidade',
#        'id_curso', 'id_turma', 'media_final', 'nota', 'numero_total_faltas',
#        'reposicao', 'unidade'],
#       dtype='object')

# %%
matriculas_geral.descricao.value_counts()
# Out:
# REPROVADO                           14079
# APROVADO POR NOTA                    9975
# APROVADO                             5664
# REPROVADO POR MÉDIA E POR FALTAS     4704
# REPROVADO POR NOTA                     48
# REPROVADO POR FALTAS                    3
# Name: descricao, dtype: int64

# %%
status_aprovado = ['APROVADO', 'APROVADO POR NOTA']

matriculas_geral['reprovou'] = matriculas_geral.descricao.apply(lambda x: False if x in status_aprovado else True)

# %%
columns_matriculas = ['discente', 'faltas_unidade',
       'id_turma', 'media_final', 'nota', 'numero_total_faltas',
       'reposicao', 'unidade', 'reprovou']
matriculas_geral = matriculas_geral[columns_matriculas]

# %%
matriculas_geral.to_csv("data/matriculas_geral_pos_preparacao.csv", sep=';', index=False)

# %% [markdown]
# ### Importando os dados de turmas

# %%
turmas_geral = pd.DataFrame()
for ano in lista_anos_analisados:
    turmas = pd.read_csv(f"data/turmas_pos_limpeza_{ano}.csv", sep=";")
    
    turmas_geral = pd.concat([turmas_geral, turmas])

# %%
turmas_geral.shape
# Out:
# (140, 6)

# %%
turmas_geral.head()
# Out:
#    Unnamed: 0  id_turma  id_componente_curricular  id_docente_interno  \
# 0        5294   1242221                     57586           5752289.0
# 1        5297   1242224                     57586           5755052.0
# 2        5301   1242227                     57586           5755040.0
# 3        5304   1242230                     57586           5757117.0
# 4        5306   1242232                     57586           5756876.0
#
#    ano_periodo situacao_turma
# 0        20151    CONSOLIDADA
# 1        20151    CONSOLIDADA
# 2        20151    CONSOLIDADA
# 3        20151    CONSOLIDADA
# 4        20151    CONSOLIDADA

# %%
turmas_geral.columns
# Out:
# Index(['Unnamed: 0', 'id_turma', 'id_componente_curricular',
#        'id_docente_interno', 'ano_periodo', 'situacao_turma'],
#       dtype='object')

# %%
columns_turma = ['id_turma', 'id_componente_curricular','id_docente_interno', 'ano_periodo']
turmas_geral = turmas_geral[columns_turma]

# %%
turmas_geral.to_csv("data/turmas_geral_pos_preparacao.csv", sep=';', index=False)

# %% [markdown]
# ## Pegando apenas os dados de Cálculo II

# %%
id_componente_c2 = ['48584', '57588', '2051052']
turmas_c2 = turmas_geral[turmas_geral.id_componente_curricular.isin(id_componente_c2)]

# %%
# Pegando apenas dos periodos que seram analisados: 2016.1, 2016.2, 2017.1
turmas_c2 = turmas_c2[turmas_c2.ano_periodo.isin(['20161', '20162', '20171'])]

# %%
turmas_c2.id_docente_interno.value_counts()
# Out:
# 5752242.0    3
# 5752287.0    2
# 5752769.0    2
# 5758125.0    2
# 5756827.0    2
# 5757166.0    1
# 5753045.0    1
# 5753037.0    1
# 5757117.0    1
# 5758644.0    1
# Name: id_docente_interno, dtype: int64

# %%
turmas_geral.id_docente_interno.value_counts()
# Out:
# 26592.0      12
# 5757193.0    11
# 5752240.0    10
# 5752289.0     8
# 5752287.0     8
# 5753020.0     7
# 5757117.0     7
# 5758125.0     7
# 5753045.0     7
# 5752242.0     6
# 5757166.0     5
# 5755052.0     4
# 5756620.0     4
# 5758715.0     4
# 5753037.0     4
# 5753081.0     4
# 5759223.0     4
# 5752170.0     4
# 5756966.0     3
# 5758220.0     3
# 5752769.0     3
# 5752727.0     3
# 5756827.0     3
# 5756876.0     2
# 5757983.0     2
# 5757657.0     1
# 5756199.0     1
# 5755040.0     1
# 5758644.0     1
# 5756031.0     1
# Name: id_docente_interno, dtype: int64

# %%
matriculas_geral[matriculas_geral.id_turma.isin(turmas_c2.id_turma.unique())]
# Out:
#                               discente  faltas_unidade  id_turma  media_final  \
# 684   324ebf7db0ca091e704046c9da1b7338             0.0  57573583          6.2
# 685   324ebf7db0ca091e704046c9da1b7338             0.0  57573583          6.2
# 686   324ebf7db0ca091e704046c9da1b7338             0.0  57573583          6.2
# 687   a3bc6f821ed792af2d8d67f97c4ddb5b             0.0  57573583          5.7
# 688   a3bc6f821ed792af2d8d67f97c4ddb5b             0.0  57573583          5.7
# 689   a3bc6f821ed792af2d8d67f97c4ddb5b             0.0  57573583          5.7
# 690   25dd0216691e1644cfb19c0bfb7ff8b3             0.0  57573583          5.5
# 691   25dd0216691e1644cfb19c0bfb7ff8b3             0.0  57573583          5.5
# 692   25dd0216691e1644cfb19c0bfb7ff8b3             0.0  57573583          5.5
# 693   621fa53cd5bf23d9d8b300354f86fa4b             0.0  57573583          5.0
# 5264  34e8f0e6ad08ca6080145deb55e9de81             0.0  57595147          1.4
# 5265  d903aa4840276efef32badaa777ac42a             0.0  57595147          2.5
# 5266  d903aa4840276efef32badaa777ac42a             0.0  57595147          2.5
# 5267  d903aa4840276efef32badaa777ac42a             0.0  57595147          2.5
# 5268  f356a6aa807bc01a79d88a2e8d3bfef3             0.0  57595147          5.1
# 5269  f356a6aa807bc01a79d88a2e8d3bfef3             0.0  57595147          5.1
# 5270  f356a6aa807bc01a79d88a2e8d3bfef3             0.0  57595147          5.1
#
#       nota  numero_total_faltas reposicao  unidade  reprovou
# 684    6.0                  2.0         f      1.0     False
# 685    6.0                  2.0         f      2.0     False
# 686    6.5                  2.0         f      3.0     False
# 687    3.0                  0.0         f      1.0     False
# 688    6.5                  0.0         f      2.0     False
# 689    7.5                  0.0         f      3.0     False
# 690    3.0                  0.0         f      1.0     False
# 691    6.0                  0.0         f      2.0     False
# 692    7.5                  0.0         f      3.0     False
# 693    4.5                  0.0         f      2.0     False
# 694    7.0                  0.0         f      3.0     False
# 695    3.5                  0.0         f      1.0     False
# 696    3.0                  2.0         t      1.0     False
# 697    4.0                  2.0         f      2.0     False
# 698    6.5                  2.0         f      3.0     False
# 699    7.0                  2.0         f      2.0     False
# 700    5.5                  2.0         f      3.0     False
# 701    5.0                  2.0         f      1.0     False
# 702    6.0                  2.0         f      1.0     False
# 703    6.5                  2.0         f      2.0     False
# 704    6.5                  2.0         f      3.0     False
# 705    5.0                  2.0         f      1.0     False
# 706    7.0                  2.0         f      2.0     False
# 707    7.0                  2.0         f      3.0     False
# 708    5.0                  0.0         f      2.0     False
# 709    6.5                  0.0         f      3.0     False
# 710    4.5                  0.0         f      1.0     False
# 711    6.5                  2.0         f      3.0     False
# 712    6.5                  2.0         f      1.0     False
# 713    6.5                  2.0         f      2.0     False
# ...    ...                  ...       ...      ...       ...
# 5241   6.4                  4.0         f      3.0     False
# 5242   4.7                  4.0         f      1.0     False
# 5243   4.3                  4.0         f      2.0     False
# 5244   6.0                  2.0         f      1.0     False
# 5245   8.4                  2.0         f      3.0     False
# 5246   2.2                  2.0         t      2.0     False
# 5247   0.0                  4.0         f      2.0      True
# 5248   4.7                  4.0         f      1.0      True
# 5249   0.0                  4.0         f      3.0      True
# 5250   2.1                  8.0         f      2.0      True
# 5251   3.0                  8.0         f      1.0      True
# 5252   3.6                  8.0         f      3.0      True
# 5253   0.0                  8.0         f      1.0      True
# 5254   0.0                  8.0         f      2.0      True
# 5255   0.0                  8.0         f      3.0      True
# 5256   2.4                  2.0         f      3.0      True
# 5257   3.7                  2.0         f      1.0      True
# 5258   0.0                  2.0         f      2.0      True
# 5259   7.2                  0.0         f      3.0     False
# 5260   6.4                  0.0         f      2.0     False
# 5261  10.0                  0.0         f      1.0     False
# 5262   0.0                  2.0         f      2.0      True
# 5263   4.3                  2.0         f      1.0      True
# 5264   0.0                  2.0         f      3.0      True
# 5265   1.6                 12.0         f      3.0      True
# 5266   0.7                 12.0         f      2.0      True
# 5267   5.3                 12.0         f      1.0      True
# 5268   4.7                  0.0         f      1.0     False
# 5269   5.1                  0.0         f      2.0     False
# 5270   5.6                  0.0         f      3.0     False
#
# [3795 rows x 9 columns]
